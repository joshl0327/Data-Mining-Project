# %%
import methods as m

# %%
start = '2007-01-01'
end = '2018-01-01'
stock_names = ['BA', 'UTX', 'HON', 'TMO', 'LMT']
stocker_stocks = m.get_stocker(stock_names)
# Out:
# BA Stocker Initialized. Data covers 1962-01-02 00:00:00 to 2018-03-27 00:00:00.
# UTX Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# HON Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# TMO Stocker Initialized. Data covers 1987-09-01 00:00:00 to 2018-03-27 00:00:00.
# LMT Stocker Initialized. Data covers 1977-01-03 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_close_df = m.get_multiple_close(stock_names, stocker_stocks, start, end)
m.plot_multiple(stock_names, stock_close_df, plot_type='basic')
m.plot_multiple(stock_names, stock_close_df, plot_type='returns')
spy = m.get_spy('yahoo',start,end)
stock_spy = m.add_spy(spy, stock_close_df)
stock_names_spy = stock_names
stock_names_spy.append('SPY')
m.plot_multiple(stock_names_spy, stock_spy, plot_type='returns')

# %%
stock_close_df_2012 = m.get_multiple_close(stock_names, stocker_stocks, start, '2012-01-01')
spy_vol = m.get_spy('yahoo',start,'2012-01-01')
stock_close_df_2012 = m.add_spy(spy_vol, stock_close_df_2012)
m.volatility(stock_close_df_2012)

# %%
m.model_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.changepoint_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 96  2015-08-14  135.655387  0.024946
# 120 2015-09-18  127.240620  0.005947
# 169 2015-11-27  138.238145 -1.628776
# 217 2016-02-08  112.387283  2.051074
# 289 2016-05-20  121.951657 -0.189368
# 458 2017-01-23  153.514602  0.318582
# 482 2017-02-27  176.025735  0.018624
# 530 2017-05-05  181.499868  0.716184
# 554 2017-06-09  187.869777  0.482445
# 602 2017-08-17  234.323387 -0.410202
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 96  2015-08-14   93.903507  0.387931
# 144 2015-10-22   94.940537 -0.024003
# 169 2015-11-27   92.693139 -0.036754
# 193 2016-01-04   91.515323  0.218195
# 217 2016-02-08   83.098250  0.727328
# 289 2016-05-20   96.220138  0.116821
# 313 2016-06-24   96.016241  0.117625
# 361 2016-09-01  104.246462 -0.519638
# 482 2017-02-27  111.529170  0.063719
# 506 2017-03-31  110.935982  0.151424
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 72  2015-07-13   98.921716 -0.231433
# 193 2016-01-04   98.825258  1.505966
# 217 2016-02-08   97.823227  0.573671
# 265 2016-04-18  111.883313 -1.675463
# 361 2016-09-01  113.703151 -0.889566
# 409 2016-11-09  110.011936  0.969121
# 433 2016-12-14  114.750903  1.176447
# 482 2017-02-27  123.658553 -0.072060
# 506 2017-03-31  123.638751 -0.182411
# 530 2017-05-05  130.114265 -0.646681
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18  124.799634  0.917083
# 144 2015-10-22  123.033507  0.024211
# 169 2015-11-27  138.869110 -0.545650
# 217 2016-02-08  121.124798  0.142518
# 265 2016-04-18  145.646447 -0.018595
# 337 2016-07-29  158.104295 -0.223608
# 361 2016-09-01  150.250840 -0.189835
# 433 2016-12-14  143.429182  0.504120
# 458 2017-01-23  142.421786  0.217899
# 602 2017-08-17  172.754817  0.277399
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08  178.016100  0.307264
# 72  2015-07-13  186.015873  0.284410
# 169 2015-11-27  215.490060 -0.490201
# 217 2016-02-08  204.634954  0.761019
# 241 2016-03-14  208.178735  0.158213
# 289 2016-05-20  230.736237 -0.169021
# 313 2016-06-24  231.963896 -0.614977
# 337 2016-07-29  244.573364 -0.415104
# 385 2016-10-06  228.709827  0.913278
# 578 2017-07-14  286.428077  0.196873

# %%
stock_close_df_cp = m.get_multiple_close(stock_names, stocker_stocks, '2015-03-30', '2018-03-27')
spy_vol = m.get_spy('yahoo','2015-03-30','2018-03-27')
stock_close_df_cp = m.add_spy(spy_vol, stock_close_df_cp)
m.volatility(stock_close_df_cp)

# %%
m.volatility(stock_close_df_2012)
