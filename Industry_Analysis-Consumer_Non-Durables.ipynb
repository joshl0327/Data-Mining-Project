# %%
import methods as m

# %%
start = '2007-01-01'
end = '2018-01-01'
stock_names = ['KO', 'PEP', 'MO', 'PM', 'NKE']
stocker_stocks = m.get_stocker(stock_names)
# Out:
# KO Stocker Initialized. Data covers 1962-01-02 00:00:00 to 2018-03-27 00:00:00.
# PEP Stocker Initialized. Data covers 1972-06-01 00:00:00 to 2018-03-27 00:00:00.
# MO Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# PM Stocker Initialized. Data covers 2008-03-17 00:00:00 to 2018-03-27 00:00:00.
# NKE Stocker Initialized. Data covers 1980-12-02 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_close_df = m.get_multiple_close(stock_names, stocker_stocks, start, end)
m.plot_multiple(stock_names, stock_close_df, plot_type='basic')
m.plot_multiple(stock_names, stock_close_df, plot_type='returns')
spy = m.get_spy('yahoo',start,end)
stock_spy = m.add_spy(spy, stock_close_df)
stock_names_spy = stock_names
stock_names_spy.append('SPY')
m.plot_multiple(stock_names_spy, stock_spy, plot_type='returns')
# Out:
# Start Date is before date range. Will choose, 2008-03-17 00:00:00, the initial stock data date as Start Date

# %%
stock_close_df_2012 = m.get_multiple_close(stock_names, stocker_stocks, start, '2012-01-01')
spy_vol = m.get_spy('yahoo',start,'2012-01-01')
stock_close_df_2012 = m.add_spy(spy_vol, stock_close_df_2012)
m.volatility(stock_close_df_2012)
# Out:
# Start Date is before date range. Will choose, 2008-03-17 00:00:00, the initial stock data date as Start Date

# %%
m.model_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.changepoint_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18   36.537372  0.487769
# 193 2016-01-04   40.047007  0.445047
# 241 2016-03-14   43.107861 -0.581522
# 265 2016-04-18   43.993053 -0.654451
# 313 2016-06-24   42.137738 -0.232968
# 337 2016-07-29   41.849978 -0.255900
# 409 2016-11-09   40.881105  0.552254
# 433 2016-12-14   40.194927  0.637525
# 554 2017-06-09   44.592826 -0.225699
# 602 2017-08-17   45.494935 -0.574933
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 144 2015-10-22   97.396827 -0.498666
# 193 2016-01-04   93.983484  0.485536
# 217 2016-02-08   92.794060  0.475653
# 337 2016-07-29  105.155384 -0.305469
# 361 2016-09-01  104.311888 -0.828772
# 385 2016-10-06  103.446592 -0.454161
# 433 2016-12-14  102.333716  1.402231
# 458 2017-01-23  101.883123  0.619710
# 554 2017-06-09  115.135104 -0.999817
# 602 2017-08-17  117.568095 -0.257771
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   43.979758  0.801056
# 120 2015-09-18   50.258593 -1.386999
# 144 2015-10-22   57.093018 -1.406821
# 193 2016-01-04   53.886216  2.826672
# 217 2016-02-08   56.449544  0.474216
# 313 2016-06-24   64.054989 -0.463004
# 337 2016-07-29   64.704905 -1.342460
# 361 2016-09-01   63.385957 -1.203670
# 433 2016-12-14   63.627708  2.816042
# 554 2017-06-09   74.065908 -2.392007
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18   73.920831  0.652513
# 169 2015-11-27   80.592091 -0.690414
# 217 2016-02-08   83.686437  0.076019
# 361 2016-09-01   95.802235 -0.835426
# 433 2016-12-14   87.282360  1.868460
# 482 2017-02-27  105.780212 -0.222994
# 506 2017-03-31  110.874199 -0.350331
# 554 2017-06-09  117.964648 -0.464598
# 578 2017-07-14  118.004743 -0.289308
# 602 2017-08-17  114.834969 -0.652302
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 96  2015-08-14   55.673189  0.418721
# 144 2015-10-22   64.623184 -2.575626
# 169 2015-11-27   65.560247 -0.849083
# 217 2016-02-08   53.855584  1.730067
# 313 2016-06-24   51.743627  0.200607
# 361 2016-09-01   57.755294 -1.386445
# 385 2016-10-06   51.332558 -0.028242
# 433 2016-12-14   51.277359  1.339313
# 458 2017-01-23   52.713006  0.269759
# 578 2017-07-14   57.802982 -0.000865

# %%
stock_close_df_cp = m.get_multiple_close(stock_names, stocker_stocks, '2015-03-30', '2018-03-27')
spy_vol = m.get_spy('yahoo','2015-03-30','2018-03-27')
stock_close_df_cp = m.add_spy(spy_vol, stock_close_df_cp)
m.volatility(stock_close_df_cp)

# %%
m.volatility(stock_close_df_2012)
