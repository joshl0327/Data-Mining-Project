# %%
import methods as m

# %%
start = '2007-01-01'
end = '2018-01-01'
stock_names = ['XOM', 'CVX', 'GE', 'BP', 'COP']
stocker_stocks = m.get_stocker(stock_names)
# Out:
# XOM Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# CVX Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# GE Stocker Initialized. Data covers 1962-01-02 00:00:00 to 2018-03-27 00:00:00.
# BP Stocker Initialized. Data covers 1977-01-03 00:00:00 to 2018-03-27 00:00:00.
# COP Stocker Initialized. Data covers 1981-12-31 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_close_df = m.get_multiple_close(stock_names, stocker_stocks, start, end)
m.plot_multiple(stock_names, stock_close_df, plot_type='basic')
m.plot_multiple(stock_names, stock_close_df, plot_type='returns')
spy = m.get_spy('yahoo',start,end)
stock_spy = m.add_spy(spy, stock_close_df)
stock_names_spy = stock_names
stock_names_spy.append('SPY')
m.plot_multiple(stock_names_spy, stock_spy, plot_type='returns')

# %%
stock_close_df_2012 = m.get_multiple_close(stock_names, stocker_stocks, start, '2012-01-01')
spy_vol = m.get_spy('yahoo',start,'2012-01-01')
stock_close_df_2012 = m.add_spy(spy_vol, stock_close_df_2012)
m.volatility(stock_close_df_2012)

# %%
m.model_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.changepoint_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18   67.025660  0.101194
# 193 2016-01-04   72.070110  2.108038
# 241 2016-03-14   77.374641 -0.194656
# 265 2016-04-18   80.538730 -0.200392
# 289 2016-05-20   84.968316 -0.303485
# 313 2016-06-24   84.636927 -0.881940
# 337 2016-07-29   84.220323 -0.930532
# 409 2016-11-09   83.096870  0.924513
# 458 2017-01-23   81.863665  0.047390
# 602 2017-08-17   76.260000 -0.313267
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18   71.409531  0.732163
# 193 2016-01-04   82.569754  1.391559
# 217 2016-02-08   79.911909  0.819645
# 265 2016-04-18   92.880744 -0.488572
# 289 2016-05-20   94.903798 -0.519056
# 313 2016-06-24   96.910482 -0.700584
# 385 2016-10-06   98.193981  0.413908
# 482 2017-02-27  109.502137 -0.458384
# 554 2017-06-09  105.335211  0.413419
# 602 2017-08-17  105.920000 -0.660407
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 24  2015-05-04   25.132294 -0.000010
# 96  2015-08-14   24.237558  0.850478
# 120 2015-09-18   23.257099  0.544371
# 144 2015-10-22   27.739717 -0.000020
# 169 2015-11-27   28.471190 -1.190458
# 337 2016-07-29   29.876633 -0.074536
# 385 2016-10-06   28.299609  0.001968
# 458 2017-01-23   28.980643 -0.601442
# 482 2017-02-27   29.398900 -0.385146
# 602 2017-08-17   24.504241 -1.057225
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 24  2015-05-04   36.501923 -0.319881
# 48  2015-06-08   34.561366 -0.313170
# 72  2015-07-13   34.075307 -0.000530
# 120 2015-09-18   26.951309  0.477552
# 193 2016-01-04   27.369614  1.039596
# 217 2016-02-08   26.365063  0.540945
# 337 2016-07-29   31.552649 -0.473249
# 361 2016-09-01   31.435073 -0.396085
# 409 2016-11-09   32.169540  0.369001
# 578 2017-07-14   34.384220  0.328536
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 144 2015-10-22   52.029569 -0.831047
# 169 2015-11-27   50.980970 -0.371892
# 217 2016-02-08   32.821145  2.720583
# 289 2016-05-20   42.110878 -0.000208
# 313 2016-06-24   41.714700 -0.079149
# 337 2016-07-29   39.684198 -0.126827
# 361 2016-09-01   39.470319 -0.000563
# 458 2017-01-23   48.838399 -0.631143
# 482 2017-02-27   46.560096 -0.130040
# 554 2017-06-09   44.309236  1.137319

# %%
stock_close_df_cp = m.get_multiple_close(stock_names, stocker_stocks, '2015-03-30', '2018-03-27')
spy_vol = m.get_spy('yahoo','2015-03-30','2018-03-27')
stock_close_df_cp = m.add_spy(spy_vol, stock_close_df_cp)
m.volatility(stock_close_df_cp)

# %%
m.volatility(stock_close_df_2012)
