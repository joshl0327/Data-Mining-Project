# %%
import methods as m

# %%
start = '2007-01-01'
end = '2018-01-01'
stock_names = ['JPM', 'BAC', 'WFC', 'C', 'AXP']
stocker_stocks = m.get_stocker(stock_names)
# Out:
# JPM Stocker Initialized. Data covers 1983-12-30 00:00:00 to 2018-03-27 00:00:00.
# BAC Stocker Initialized. Data covers 1986-05-29 00:00:00 to 2018-03-27 00:00:00.
# WFC Stocker Initialized. Data covers 1972-06-01 00:00:00 to 2018-03-27 00:00:00.
# C Stocker Initialized. Data covers 1977-01-03 00:00:00 to 2018-03-27 00:00:00.
# AXP Stocker Initialized. Data covers 1972-06-01 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_close_df = m.get_multiple_close(stock_names, stocker_stocks, start, end)
m.plot_multiple(stock_names, stock_close_df, plot_type='basic')
m.plot_multiple(stock_names, stock_close_df, plot_type='returns')
spy = m.get_spy('yahoo',start,end)
stock_spy = m.add_spy(spy, stock_close_df)
stock_names_spy = stock_names
stock_names_spy.append('SPY')
m.plot_multiple(stock_names_spy, stock_spy, plot_type='returns')

# %%
stock_close_df_2012 = m.get_multiple_close(stock_names, stocker_stocks, start, '2012-01-01')
spy_vol = m.get_spy('yahoo',start,'2012-01-01')
stock_close_df_2012 = m.add_spy(spy_vol, stock_close_df_2012)
m.volatility(stock_close_df_2012)

# %%
m.model_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.changepoint_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   62.662770 -0.561410
# 72  2015-07-13   64.199248 -0.659191
# 169 2015-11-27   63.790065 -1.007690
# 217 2016-02-08   54.066315  2.287690
# 289 2016-05-20   61.182752 -0.386573
# 337 2016-07-29   62.108763  0.376308
# 385 2016-10-06   66.370212  0.248350
# 433 2016-12-14   82.857640 -0.188311
# 482 2017-02-27   88.920086 -0.576257
# 554 2017-06-09   85.997705  0.486506
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   16.533203 -0.049705
# 72  2015-07-13   16.475124 -1.302215
# 96  2015-08-14   17.133354 -0.295136
# 144 2015-10-22   15.692001 -0.420229
# 169 2015-11-27   16.973774 -1.396683
# 217 2016-02-08   11.948467  3.136144
# 337 2016-07-29   14.210558  0.118071
# 385 2016-10-06   15.981113  0.095478
# 482 2017-02-27   24.294101 -0.460501
# 554 2017-06-09   23.551601  0.116753
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   52.167111 -0.013553
# 72  2015-07-13   52.743441 -0.511910
# 96  2015-08-14   53.638535 -0.531966
# 144 2015-10-22   50.579089 -0.513977
# 193 2016-01-04   49.843256  0.196058
# 217 2016-02-08   44.149890  1.352501
# 289 2016-05-20   46.645569 -0.322499
# 385 2016-10-06   43.575007  0.166803
# 409 2016-11-09   46.673963  0.459814
# 482 2017-02-27   56.851603 -0.562435
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 72  2015-07-13   54.137999 -0.931755
# 96  2015-08-14   56.183921 -0.194781
# 169 2015-11-27   52.935724 -0.174356
# 217 2016-02-08   36.966933  1.562862
# 265 2016-04-18   44.104161 -0.404990
# 289 2016-05-20   43.945815 -0.095396
# 337 2016-07-29   43.034619  0.537254
# 385 2016-10-06   48.201524  0.661922
# 482 2017-02-27   59.322544 -0.523214
# 602 2017-08-17   66.313433 -0.095508
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   75.530925 -0.736707
# 120 2015-09-18   73.061526 -0.371342
# 144 2015-10-22   70.004789 -0.731463
# 217 2016-02-08   50.824336  3.597450
# 265 2016-04-18   61.001933 -1.138272
# 289 2016-05-20   62.298187 -1.004349
# 385 2016-10-06   60.963630  0.762412
# 409 2016-11-09   67.656440  0.948816
# 433 2016-12-14   72.902423  0.037462
# 482 2017-02-27   79.237371 -0.866424

# %%
stock_close_df_cp = m.get_multiple_close(stock_names, stocker_stocks, '2015-03-30', '2018-03-27')
spy_vol = m.get_spy('yahoo','2015-03-30','2018-03-27')
stock_close_df_cp = m.add_spy(spy_vol, stock_close_df_cp)
m.volatility(stock_close_df_cp)

# %%
m.volatility(stock_close_df_2012)
