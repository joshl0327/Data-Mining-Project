# %%
import methods as m

# %%
start = '2007-01-01'
end = '2018-01-01'
stock_names = ['JNJ', 'UNH', 'PFE', 'MRK', 'ABBV']
stocker_stocks = m.get_stocker(stock_names)
# Out:
# JNJ Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# UNH Stocker Initialized. Data covers 1990-03-26 00:00:00 to 2018-03-27 00:00:00.
# PFE Stocker Initialized. Data covers 1972-06-01 00:00:00 to 2018-03-27 00:00:00.
# MRK Stocker Initialized. Data covers 1970-01-02 00:00:00 to 2018-03-27 00:00:00.
# ABBV Stocker Initialized. Data covers 2013-01-02 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_close_df = m.get_multiple_close(stock_names, stocker_stocks, start, end)
m.plot_multiple(stock_names, stock_close_df, plot_type='basic')
m.plot_multiple(stock_names, stock_close_df, plot_type='returns')
spy = m.get_spy('yahoo',start,end)
stock_spy = m.add_spy(spy, stock_close_df)
stock_names_spy = stock_names
stock_names_spy.append('SPY')
m.plot_multiple(stock_names_spy, stock_spy, plot_type='returns')
# Out:
# Start Date is before date range. Will choose, 2013-01-02 00:00:00, the initial stock data date as Start Date

# %%
stock_close_df_2012 = m.get_multiple_close(stock_names, stocker_stocks, start, '2012-01-01')
spy_vol = m.get_spy('yahoo',start,'2012-01-01')
stock_close_df_2012 = m.add_spy(spy_vol, stock_close_df_2012)
m.volatility(stock_close_df_2012)
# Out:
# Start Date is before date range. Will choose, 2013-01-02 00:00:00, the initial stock data date as Start Date

# %%
m.model_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.changepoint_stocker(stocker_stocks)
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 193 2016-01-04   95.264931  1.843661
# 265 2016-04-18  105.929851 -0.830678
# 337 2016-07-29  120.434608 -1.129992
# 361 2016-09-01  115.284085 -0.903900
# 433 2016-12-14  112.096476  1.988631
# 458 2017-01-23  111.043652  1.163651
# 482 2017-02-27  120.097789 -0.231448
# 506 2017-03-31  122.207350 -1.104992
# 554 2017-06-09  129.906115 -0.478633
# 602 2017-08-17  131.397472 -0.366752
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 120 2015-09-18  118.481896 -0.581129
# 144 2015-10-22  110.103900 -0.270328
# 193 2016-01-04  113.146472  1.619295
# 217 2016-02-08  106.889703  0.683986
# 265 2016-04-18  124.686231 -0.953001
# 289 2016-05-20  127.739731 -0.252403
# 385 2016-10-06  134.360005  0.249681
# 409 2016-11-09  139.706051  0.229159
# 458 2017-01-23  157.228833  0.396853
# 602 2017-08-17  191.973452 -0.227031
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 217 2016-02-08   26.740170  0.834908
# 241 2016-03-14   28.182042  0.677041
# 289 2016-05-20   31.875900 -0.433170
# 313 2016-06-24   32.093192 -0.776759
# 337 2016-07-29   34.851865 -1.086244
# 409 2016-11-09   30.909403  1.708697
# 433 2016-12-14   31.583020  0.629234
# 482 2017-02-27   33.321310 -0.755794
# 506 2017-03-31   33.253268 -1.014018
# 578 2017-07-14   32.809899  0.935603
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 24  2015-05-04   56.059336 -0.000208
# 48  2015-06-08   54.423039 -0.101968
# 72  2015-07-13   53.907241 -0.001402
# 120 2015-09-18   48.979806  0.996059
# 169 2015-11-27   50.699220 -0.000007
# 217 2016-02-08   46.283911  0.293815
# 289 2016-05-20   52.688128  0.049481
# 313 2016-06-24   53.862272  0.062598
# 482 2017-02-27   64.431033 -0.667981
# 506 2017-03-31   62.626309 -0.293721
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-06-08   61.854679 -0.217827
# 72  2015-07-13   63.944179 -0.362612
# 120 2015-09-18   56.269407  0.108661
# 144 2015-10-22   44.787192  0.477456
# 216 2016-02-05   49.836172  0.064566
# 409 2016-11-09   60.414403  0.088013
# 433 2016-12-14   59.478867  0.000140
# 553 2017-06-08   67.679382  0.420904
# 577 2017-07-13   72.125077  0.722296
# 601 2017-08-16   69.930441  0.488345

# %%
stock_close_df_cp = m.get_multiple_close(stock_names, stocker_stocks, '2015-03-30', '2018-03-27')
spy_vol = m.get_spy('yahoo','2015-03-30','2018-03-27')
stock_close_df_cp = m.add_spy(spy_vol, stock_close_df_cp)
m.volatility(stock_close_df_cp)

# %%
m.volatility(stock_close_df_2012)
