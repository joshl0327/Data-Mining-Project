# %%
'''
# !pip install pandas_datareader
# !pip install fix_yahoo_finance
# !pip install mpl_finance
'''
# Out:
# '\n!pip install pandas_datareader\n!pip install fix_yahoo_finance\n!pip install mpl_finance\n'

# %%
import methods as m
import datetime
import matplotlib.pyplot as plt

#from pandas_datareader import data #not sure if we'll need this
#import pandas as pd
#import fix_yahoo_finance as yf
#import numpy as np

start = '2007-01-01'
end = '2018-01-01'

# %%
spy = m.get_spy('yahoo',start,end)

# %%
#Top by Market Cap from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Technology&sortname=marketcap&sorttype=1
#tech_names = ['AAPL', 'MSFT', 'GOOGL', 'GOOG', 'FB', 'INTC', 'CSCO', 'TSM', 'ORCL', 'SAP']
tech_names = ['AAPL', 'MSFT', 'GOOGL', 'FB', 'INTC']
tech_stocks = m.get_stocks(tech_names,start,end)
tech_close = m.get_close(tech_stocks)
# Out:
# [*********************100%***********************]  5 of 5 downloaded

# %%
tech_returns = m.get_returns(tech_close)

# %%
tech_close_spy = m.add_spy(spy,tech_close)
tech_returns_spy = m.get_returns(tech_close_spy)

# %%
tech_stocks["Adj Close"].head()
# Out:
#                 AAPL  FB       GOOGL       INTC       MSFT
# Date
# 2007-01-03  8.016820 NaN  234.029022  14.138523  22.574831
# 2007-01-04  8.194759 NaN  241.871872  14.708237  22.537027
# 2007-01-05  8.136404 NaN  243.838837  14.659607  22.408501
# 2007-01-08  8.176582 NaN  242.032028  14.597075  22.627748
# 2007-01-09  8.855811 NaN  242.992996  14.610971  22.650431

# %%
start2010 = datetime.datetime(2010,1,1)
m.candlestick('AAPL',start2010,end)

# %%
m.candlestick('FB',start2010,end)

# %%
m.candlestick('GOOG',start2010,end)

# %%
m.candlestick('INTC',start2010,end)

# %%
m.candlestick('MSFT',start2010,end)

# %%
#Top from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Energy&sortname=marketcap&sorttype=1
#energy_names = ['XOM', 'CVX', 'TOT', 'BP', 'PTR', 'BBL', 'SNP', 'PBR', 'EQNR', 'COP']
energy_names = ['XOM', 'CVX', 'TOT', 'BP', 'PTR']
energy_stocks = m.get_stocks(energy_names,start,end)
energy_close = m.get_close(energy_stocks)
# Out:
# [*********************100%***********************]  5 of 5 downloaded

# %%
energy_return = m.get_returns(energy_close)

# %%
energy_close_spy = m.add_spy(spy,energy_close)
energy_returns_spy = m.get_returns(energy_close_spy)

# %%
#Top from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Finance&sortname=marketcap&sorttype=1
#finance_names = ['JPM', 'BAC', 'WFC', 'HSBC', 'C', 'ITUB', 'RY', 'TD', 'AXP', 'HDB']
finance_names = ['JPM', 'BAC', 'WFC', 'HSBC', 'C']
finance_stocks = m.get_stocks(finance_names,start,end)
finance_close = m.get_close(finance_stocks)
# Out:
# [*********************100%***********************]  5 of 5 downloaded

# %%
finance_return = m.get_returns(finance_close)

# %%
finance_close_spy = m.add_spy(spy,finance_close)
finance_returns_spy = m.get_returns(finance_close_spy)

# %%
from stocker import Stocker

# %%
apple = Stocker('AAPL')
microsoft = Stocker('MSFT')
google = Stocker('GOOGL')
facebook = Stocker('FB')
intel = Stocker('INTC')
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.
# MSFT Stocker Initialized. Data covers 1986-03-13 00:00:00 to 2018-03-27 00:00:00.
# GOOGL Stocker Initialized. Data covers 2004-08-19 00:00:00 to 2018-03-27 00:00:00.
# FB Stocker Initialized. Data covers 2012-05-18 00:00:00 to 2018-03-27 00:00:00.
# INTC Stocker Initialized. Data covers 1980-03-17 00:00:00 to 2018-03-27 00:00:00.

# %%
apple.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Maximum Daily Change = 7.94 on 2015-08-24 00:00:00.
# Minimum Daily Change = -7.09 on 2015-08-25 00:00:00.
# Current Daily Change = -5.34 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 1855410200.00 on 2000-09-29 00:00:00.
# Minimum Adj. Volume = 9835000.00 on 2002-12-24 00:00:00.
# Current Adj. Volume = 38962839.00 on 2018-03-27 00:00:00.

# %%
microsoft.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Maximum Daily Change = 2.08 on 2008-10-13 00:00:00.
# Minimum Daily Change = -3.34 on 2017-12-04 00:00:00.
# Current Daily Change = -5.47 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 591052200.00 on 2006-04-28 00:00:00.
# Minimum Adj. Volume = 7425503.00 on 2017-11-24 00:00:00.
# Current Adj. Volume = 53704562.00 on 2018-03-27 00:00:00.

# %%
google.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Start Date is before date range. Will choose, 2004-08-19 00:00:00, the initial stock data date as Start Date
# Maximum Daily Change = 20.87 on 2016-03-01 00:00:00.
# Minimum Daily Change = -36.90 on 2016-02-03 00:00:00.
# Current Daily Change = -56.96 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 82151100.00 on 2006-01-20 00:00:00.
# Minimum Adj. Volume = 521141.00 on 2015-12-24 00:00:00.
# Current Adj. Volume = 2940957.00 on 2018-03-27 00:00:00.

# %%
facebook.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Start Date is before date range. Will choose, 2012-05-18 00:00:00, the initial stock data date as Start Date
# Maximum Daily Change = 5.06 on 2015-08-24 00:00:00.
# Minimum Daily Change = -6.76 on 2017-11-29 00:00:00.
# Current Daily Change = -4.12 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 573576400.00 on 2012-05-18 00:00:00.
# Minimum Adj. Volume = 5913066.00 on 2015-11-27 00:00:00.
# Current Adj. Volume = 76787884.00 on 2018-03-27 00:00:00.

# %%
intel.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Maximum Daily Change = 4.37 on 2000-04-17 00:00:00.
# Minimum Daily Change = -3.15 on 2000-09-25 00:00:00.
# Current Daily Change = -1.82 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 309347600.00 on 2008-01-16 00:00:00.
# Minimum Adj. Volume = 1155400.00 on 2000-12-01 00:00:00.
# Current Adj. Volume = 37076576.00 on 2018-03-27 00:00:00.

# %%
model, model_data = apple.create_prophet_model()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
model.plot_components(model_data)
plt.show()

# %%
model, model_data = microsoft.create_prophet_model()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
model.plot_components(model_data)
plt.show()

# %%
model, model_data = google.create_prophet_model()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
model.plot_components(model_data)
plt.show()

# %%
model, model_data = facebook.create_prophet_model()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
model.plot_components(model_data)
plt.show()

# %%
model, model_data = intel.create_prophet_model()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
apple.changepoint_date_analysis()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 433 2016-12-14  113.767235  1.063407
# 288 2016-05-19   92.060491  0.772369
# 48  2015-06-08  122.392291 -0.622993
# 529 2017-05-04  145.343086 -0.425737
# 481 2017-02-24  135.553035 -0.337295
# 216 2016-02-05   91.326278  0.331918
# 505 2017-03-30  142.764147 -0.272297
# 409 2016-11-09  109.510470  0.163036
# 361 2016-09-01  104.867483 -0.157710
# 120 2015-09-18  109.140225  0.058418

# %%
microsoft.changepoint_date_analysis()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 361 2016-09-01   55.966886 -1.319902
# 169 2015-11-27   51.353167 -1.128169
# 289 2016-05-20   48.886934  0.847661
# 506 2017-03-31   64.816957  0.580521
# 120 2015-09-18   41.122995  0.571162
# 313 2016-06-24   48.123981  0.518528
# 24  2015-05-04   45.034285 -0.513749
# 48  2015-06-08   42.969230 -0.358889
# 409 2016-11-09   58.474172  0.353326
# 217 2016-02-08   47.049138  0.196015

# %%
google.changepoint_date_analysis()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 554 2017-06-09      970.12 -2.131440
# 602 2017-08-17      927.66  1.547839
# 433 2016-12-14      817.89  0.716763
# 169 2015-11-27      771.97 -0.556216
# 458 2017-01-23      844.43  0.551600
# 506 2017-03-31      847.80  0.246044
# 361 2016-09-01      791.40 -0.234755
# 48  2015-06-08      543.48  0.208303
# 385 2016-10-06      803.08 -0.170959
# 313 2016-06-24      685.20  0.113864

# %%
facebook.changepoint_date_analysis()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 433 2016-12-14      120.21  1.669034
# 602 2017-08-17      166.91 -0.655597
# 361 2016-09-01      126.17 -0.479707
# 385 2016-10-06      128.74 -0.442266
# 289 2016-05-20      117.35 -0.386399
# 217 2016-02-08       99.75  0.236570
# 409 2016-11-09      123.18  0.200170
# 530 2017-05-05      150.24 -0.143297
# 506 2017-03-31      142.05 -0.131403
# 120 2015-09-18       94.40  0.101451

# %%
intel.changepoint_date_analysis()
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 361 2016-09-01   34.566192 -2.612703
# 409 2016-11-09   33.602987  1.624492
# 288 2016-05-19   28.219876  1.534747
# 577 2017-07-13   33.591844  0.647328
# 601 2017-08-17   34.762382  0.576040
# 457 2017-01-20   35.720700 -0.478332
# 168 2015-11-25   32.241456 -0.416618
# 96  2015-08-14   26.970026  0.372187
# 240 2016-03-11   29.987311  0.132553
# 553 2017-06-08   35.789441  0.057792
