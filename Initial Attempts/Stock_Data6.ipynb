# %%
import methods as m
import datetime
import matplotlib.pyplot as plt

start = '2007-01-01'
end = '2018-01-01'

# %%
kw_list = ['Stock Crash']
date_range = '2007-01-01 2012-01-01'

# %%
tech_names = ['AAPL']
              #, 'MSFT', 'GOOGL', 'FB', 'INTC']
stocker_tech = m.get_stocker(tech_names)
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.

# %%
trends, related_queries = stocker_tech[0].custom_trends_retrieval(kw_list, date_range)

# %%
print(trends)
print(related_queries)
# Out:
#             Stock Crash isPartial
# date
# 2007-01-07            0      True
# 2007-01-14            0      True
# 2007-01-21            0      True
# 2007-01-28            0      True
# 2007-02-04            0      True
# 2007-02-11            0      True
# 2007-02-18            0      True
# 2007-02-25            0      True
# 2007-03-04            0      True
# 2007-03-11            0      True
# 2007-03-18            0      True
# 2007-03-25            0      True
# 2007-04-01            0      True
# 2007-04-08            0      True
# 2007-04-15            0      True
# 2007-04-22            0      True
# 2007-04-29            0      True
# 2007-05-06            0      True
# 2007-05-13            0      True
# 2007-05-20            0      True
# 2007-05-27            0      True
# 2007-06-03            0      True
# 2007-06-10            0      True
# 2007-06-17            0      True
# 2007-06-24            0      True
# 2007-07-01            0      True
# ...

# %%
trends.plot()
plt.show()

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(kw_list,cat=0, timeframe=date_range, geo='', gprop='news')
trends = pytrends.interest_over_time()
related_queries = pytrends.related_queries()

# %%
print(trends)
print(related_queries)
# Out:
#             Stock Crash isPartial
# date
# 2007-01-07            0      True
# 2007-01-14            0      True
# 2007-01-21            0      True
# 2007-01-28            0      True
# 2007-02-04            0      True
# 2007-02-11            0      True
# 2007-02-18            0      True
# 2007-02-25            0      True
# 2007-03-04            0      True
# 2007-03-11            0      True
# 2007-03-18            0      True
# 2007-03-25            0      True
# 2007-04-01            0      True
# 2007-04-08            0      True
# 2007-04-15            0      True
# 2007-04-22            0      True
# 2007-04-29            0      True
# 2007-05-06            0      True
# 2007-05-13            0      True
# 2007-05-20            0      True
# 2007-05-27            0      True
# 2007-06-03            0      True
# 2007-06-10            0      True
# 2007-06-17            0      True
# 2007-06-24            0      True
# 2007-07-01            0      True
# ...

# %%
trends.plot()
plt.show()

# %%
stocker_tech[0].changepoint_date_analysis(search = 'Microsoft profit')
# Out:
# D:\Anaconda\envs\py36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# 2015-03-30 00:00:00
#
# Google Search Trend retrieval failed.
# The request failed: Google returned a response with code 400.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-aed6288d0732> in <module>
# ----> 1 stocker_tech[0].changepoint_date_analysis(search = 'Microsoft profit')
#
# ~\Desktop\Untitled Folder\stocker.py in changepoint_date_analysis(self, search)
#     779             #
#     780             #This has been modified by us as previously this function would repeatedly cause errors
# ...
