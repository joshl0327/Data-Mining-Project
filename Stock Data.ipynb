# %%
from pandas_datareader import data #not sure if we'll need this
import matplotlib.pyplot as plt
import pandas as pd
import fix_yahoo_finance as yf

# %%
'''
Currently having issues with DataReader due to issues with google/yahoo API

# Define the instruments to download.
#Top  from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Technology&sortname=marketcap&sorttype=1
tickers = ['AAPL', 'MSFT', 'GOOGL', 'GOOG', 'FB', 'INTC', 'CSCO', 'TSM', 'ORCL', 'SAP']

#Time interval
start_date = '2014-01-01'
end_date = '2016-12-31'

panel_data = data.DataReader('INPX', 'yahoo', start_date, end_date)
panel_data.to_frame().head(10)
'''
# Out:
# "\nCurrently having issues with DataReader due to issues with google/yahoo API\n\n# Define the instruments to download.\n#Top  from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Technology&sortname=marketcap&sorttype=1\ntickers = ['AAPL', 'MSFT', 'GOOGL', 'GOOG', 'FB', 'INTC', 'CSCO', 'TSM', 'ORCL', 'SAP']\n\n#Time interval\nstart_date = '2014-01-01'\nend_date = '2016-12-31'\n\npanel_data = data.DataReader('INPX', 'yahoo', start_date, end_date)\npanel_data.to_frame().head(10)\n"

# %%
import fix_yahoo_finance as yf

# %%
#Top by Market Cap from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Technology&sortname=marketcap&sorttype=1
tech = ['AAPL', 'MSFT', 'GOOGL', 'GOOG', 'FB', 'INTC', 'CSCO', 'TSM', 'ORCL', 'SAP']
data = yf.download(tech,'2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  10 of 10 downloaded

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
tech_noGOOG = ['AAPL', 'MSFT', 'FB', 'INTC', 'CSCO', 'TSM', 'ORCL', 'SAP']
data = yf.download(tech_noGOOG,'2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  8 of 8 downloaded

# %%
tech_GOOG = ['GOOGL', 'GOOG']
data = yf.download(tech_GOOG,'2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 downloaded

# %%
#Top from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Energy&sortname=marketcap&sorttype=1
energy = ['XOM', 'CVX', 'TOT', 'BP', 'PTR', 'BBL', 'SNP', 'PBR', 'EQNR', 'COP']
data = yf.download(energy,'2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  10 of 10 downloaded

# %%
#Top from https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Finance&sortname=marketcap&sorttype=1
finance = ['JPM', 'BAC', 'WFC', 'HSBC', 'C', 'ITUB', 'RY', 'TD', 'AXP', 'HDB']
data = yf.download(finance,'2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  10 of 10 downloaded
